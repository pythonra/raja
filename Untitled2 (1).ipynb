# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-f8690427-e476-48a7-88d2-08cdc8859095" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f8690427-e476-48a7-88d2-08cdc8859095">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("kanpur.csv")
df.head()
# Out:
#              date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2009-01-01 00:00:00        24        10           0.0      8.7        4
# 1  2009-01-01 01:00:00        24        10           0.0      8.7        4
# 2  2009-01-01 02:00:00        24        10           0.0      8.7        4
# 3  2009-01-01 03:00:00        24        10           0.0      8.7        4
# 4  2009-01-01 04:00:00        24        10           0.0      8.7        4
#
#    uvIndex.1  moon_illumination  moonrise   moonset  ... WindChillC  \
# 0          1                 31  09:56 AM  09:45 PM  ...         11
# 1          1                 31  09:56 AM  09:45 PM  ...         12
# 2          1                 31  09:56 AM  09:45 PM  ...         12
# 3          1                 31  09:56 AM  09:45 PM  ...         12
# 4          1                 31  09:56 AM  09:45 PM  ...         14
#
#   WindGustKmph  cloudcover  humidity  precipMM  pressure  tempC  visibility  \
# ...

# %%
cdf = df[['maxtempC','mintempC','cloudcover','humidity','pressure','precipMM']]
cdf.head(15)
# Out:
#     maxtempC  mintempC  cloudcover  humidity  pressure  precipMM
# 0         24        10          17        50      1015       0.0
# 1         24        10          11        52      1015       0.0
# 2         24        10           6        55      1015       0.0
# 3         24        10           0        57      1015       0.0
# 4         24        10           0        54      1016       0.0
# 5         24        10           0        52      1016       0.0
# 6         24        10           0        49      1017       0.0
# 7         24        10           0        44      1017       0.0
# 8         24        10           0        38      1017       0.0
# 9         24        10           0        33      1017       0.0
# 10        24        10           1        31      1016       0.0
# 11        24        10           2        30      1015       0.0
# 12        24        10           2        28      1014       0.0
# ...

# %%
plt.scatter(cdf.maxtempC, cdf.precipMM, color="blue")
plt.xlabel("maxtempC")
plt.ylabel("precipMM")
plt.show()

# %%
plt.scatter(cdf.mintempC, cdf.precipMM, color="blue")
plt.xlabel("mintempC")
plt.ylabel("precipMM")
plt.show()

# %%
plt.scatter(cdf.humidity, cdf.precipMM, color="blue")
plt.xlabel("huminity")
plt.ylabel("precipMM")
plt.show()

# %%
plt.scatter(cdf.pressure, cdf.precipMM, color="blue")
plt.xlabel("pressure")
plt.ylabel("precipMM")
plt.show()

# %%
plt.scatter(cdf.cloudcover, cdf.precipMM, color="blue")
plt.xlabel("cloudcover")
plt.ylabel("precipMM")
plt.show()

# %%
msk = np.random.rand(len(df)) <0.8
train = cdf[msk]
test = cdf[msk]

# %%
from sklearn import linear_model

regr = linear_model.LinearRegression()
x = np.asanyarray(train[['maxtempC','mintempC','cloudcover','humidity','pressure']])
y = np.asanyarray(train['precipMM'])
regr.fit (x, y)
print ('Coefficients: ', regr.coef_)


y_hat= regr.predict(test[['maxtempC','mintempC','cloudcover','humidity','pressure']])
x = np.asanyarray(test[['maxtempC','mintempC','cloudcover','humidity','pressure']])
y = np.asanyarray(test['precipMM'])

print ("Residual sum of squares: %.2f" % np.mean((y_hat - y) ** 2))

# Explained variance score: 1 is perfect prediction
print ('Variance score: %.2f' % regr.score(x, y))
# Out:
# Coefficients:  [-0.0021641  -0.00184248  0.00235517  0.00071635 -0.00475939]
# Residual sum of squares: 0.09
# Variance score: 0.06
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
